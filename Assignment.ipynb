# %%
#import the required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm

# %%
# read csv file using pandas
df = pd.read_csv("cancer_reg (1) (1) (1).csv" , encoding='latin-1')

# display the top 5 rows of the dataframe
df.head()
# Out:
#    avgAnnCount  avgDeathsPerYear  TARGET_deathRate  incidenceRate  medIncome  \
# 0       1397.0               469             164.9          489.8      61898
# 1        173.0                70             161.3          411.6      48127
# 2        102.0                50             174.7          349.7      49348
# 3        427.0               202             194.8          430.4      44243
# 4         57.0                26             144.4          350.1      49955
#
#    popEst2015  povertyPercent  studyPerCap           binnedInc  MedianAge  \
# 0      260131            11.2   499.748204   (61494.5, 125635]       39.3
# 1       43269            18.6    23.111234  (48021.6, 51046.4]       33.0
# 2       21026            14.6    47.560164  (48021.6, 51046.4]       45.0
# 3       75882            17.1   342.637253    (42724.4, 45201]       42.8
# 4       10321            12.5     0.000000  (48021.6, 51046.4]       48.3
#
#    ...  PctPrivateCoverageAlone  PctEmpPrivCoverage PctPublicCoverage  \
# 0  ...                      NaN                41.6              32.9
# 1  ...                     53.8                43.6              31.1
# 2  ...                     43.5                34.9              42.1
# 3  ...                     40.3                35.0              45.3
# 4  ...                     43.9                35.1              44.0
#
#    PctPublicCoverageAlone   PctWhite  PctBlack  PctAsian  PctOtherRace  \
# 0                    14.0  81.780529  2.594728  4.821857      1.843479
# 1                    15.3  89.228509  0.969102  2.246233      3.741352
# 2                    21.1  90.922190  0.739673  0.465898      2.747358
# 3                    25.0  91.744686  0.782626  1.161359      1.362643
# 4                    22.7  94.104024  0.270192  0.665830      0.492135
#
#    PctMarriedHouseholds  BirthRate
# 0             52.856076   6.118831
# 1             45.372500   4.333096
# 2             54.444868   3.729488
# 3             51.021514   4.603841
# 4             54.027460   6.796657
#
# [5 rows x 34 columns]

# %%
#Printing the shape of data
df.shape
# Out:
# (3047, 34)

# %%
# use .dtypes to view the data type of a variable
df.dtypes
# Out:
# avgAnnCount                float64
# avgDeathsPerYear             int64
# TARGET_deathRate           float64
# incidenceRate              float64
# medIncome                    int64
# popEst2015                   int64
# povertyPercent             float64
# studyPerCap                float64
# binnedInc                   object
# MedianAge                  float64
# MedianAgeMale              float64
# MedianAgeFemale            float64
# Geography                   object
# AvgHouseholdSize           float64
# PercentMarried             float64
# PctNoHS18_24               float64
# PctHS18_24                 float64
# PctSomeCol18_24            float64
# PctBachDeg18_24            float64
# PctHS25_Over               float64
# PctBachDeg25_Over          float64
# PctEmployed16_Over         float64
# PctUnemployed16_Over       float64
# PctPrivateCoverage         float64
# PctPrivateCoverageAlone    float64
# PctEmpPrivCoverage         float64
# PctPublicCoverage          float64
# PctPublicCoverageAlone     float64
# PctWhite                   float64
# PctBlack                   float64
# PctAsian                   float64
# PctOtherRace               float64
# PctMarriedHouseholds       float64
# BirthRate                  float64
# dtype: object

# %%
# describe the numerical data
df.describe()
# Out:
#         avgAnnCount  avgDeathsPerYear  TARGET_deathRate  incidenceRate  \
# count   3047.000000       3047.000000       3047.000000    3047.000000
# mean     606.338544        185.965868        178.664063     448.268586
# std     1416.356223        504.134286         27.751511      54.560733
# min        6.000000          3.000000         59.700000     201.300000
# 25%       76.000000         28.000000        161.200000     420.300000
# 50%      171.000000         61.000000        178.100000     453.549422
# 75%      518.000000        149.000000        195.200000     480.850000
# max    38150.000000      14010.000000        362.800000    1206.900000
#
#            medIncome    popEst2015  povertyPercent  studyPerCap    MedianAge  \
# count    3047.000000  3.047000e+03     3047.000000  3047.000000  3047.000000
# mean    47063.281917  1.026374e+05       16.878175   155.399415    45.272333
# std     12040.090836  3.290592e+05        6.409087   529.628366    45.304480
# min     22640.000000  8.270000e+02        3.200000     0.000000    22.300000
# 25%     38882.500000  1.168400e+04       12.150000     0.000000    37.700000
# 50%     45207.000000  2.664300e+04       15.900000     0.000000    41.000000
# 75%     52492.000000  6.867100e+04       20.400000    83.650776    44.000000
# max    125635.000000  1.017029e+07       47.400000  9762.308998   624.000000
#
#        MedianAgeMale  ...  PctPrivateCoverageAlone  PctEmpPrivCoverage  \
# count    3047.000000  ...              2438.000000         3047.000000
# mean       39.570725  ...                48.453774           41.196324
# std         5.226017  ...                10.083006            9.447687
# min        22.400000  ...                15.700000           13.500000
# 25%        36.350000  ...                41.000000           34.500000
# 50%        39.600000  ...                48.700000           41.100000
# 75%        42.500000  ...                55.600000           47.700000
# max        64.700000  ...                78.900000           70.700000
#
#        PctPublicCoverage  PctPublicCoverageAlone     PctWhite     PctBlack  \
# count        3047.000000             3047.000000  3047.000000  3047.000000
# mean           36.252642               19.240072    83.645286     9.107978
# std             7.841741                6.113041    16.380025    14.534538
# min            11.200000                2.600000    10.199155     0.000000
# 25%            30.900000               14.850000    77.296180     0.620675
# 50%            36.300000               18.800000    90.059774     2.247576
# 75%            41.550000               23.100000    95.451693    10.509732
# max            65.100000               46.600000   100.000000    85.947799
#
#           PctAsian  PctOtherRace  PctMarriedHouseholds    BirthRate
# count  3047.000000   3047.000000           3047.000000  3047.000000
# mean      1.253965      1.983523             51.243872     5.640306
# std       2.610276      3.517710              6.572814     1.985816
# min       0.000000      0.000000             22.992490     0.000000
# 25%       0.254199      0.295172             47.763063     4.521419
# 50%       0.549812      0.826185             51.669941     5.381478
# 75%       1.221037      2.177960             55.395132     6.493677
# max      42.619425     41.930251             78.075397    21.326165
#
# [8 rows x 32 columns]

# %%
# describe the categorical data
# include=object: selects the categorical features
df.describe(include = object)
# Out:
#                binnedInc           Geography
# count               3047                3047
# unique                10                3047
# top     [22640, 34218.1]  Bell County, Texas
# freq                 306                   1

# %%
# obtain the total missing values for each variable
# 'isnull().sum()' returns the number of missing values in each variable
# sort the variables on the basis of total null values in the variable using sort_values()
# 'ascending = False' sorts values in the descending order
# the variable with highest number of missing values will appear first
Total = df.isnull().sum().sort_values(ascending=False) 

# 'isnull().sum()' returns the number of missing values in each variable
# 'isnull().count()' returns the count of the data, i.e. count of outcomes 'True' and 'False' of isnull() 
# sort the variables on the basis of total null values in the variable using sort_values()
# 'ascending = False' sorts values in the descending order
# the variable with highest percentage of missing values will appear first
Percent = (df.isnull().sum()*100/df.isnull().count()).sort_values(ascending=False)   

# concat the 'Total' and 'Percent' columns using 'concat' function
# keys:pass a list of column names in parameter  
# axis = 1: concats along the columns
missing_data = pd.concat([Total, Percent], axis = 1, keys = ['Total', 'Percentage of Missing Values'])

# print the missing data
missing_data
# Out:
#                          Total  Percentage of Missing Values
# PctSomeCol18_24           2285                     74.991795
# PctPrivateCoverageAlone    609                     19.986872
# PctEmployed16_Over         152                      4.988513
# PercentMarried               0                      0.000000
# Geography                    0                      0.000000
# MedianAgeFemale              0                      0.000000
# MedianAgeMale                0                      0.000000
# MedianAge                    0                      0.000000
# binnedInc                    0                      0.000000
# BirthRate                    0                      0.000000
# studyPerCap                  0                      0.000000
# povertyPercent               0                      0.000000
# popEst2015                   0                      0.000000
# medIncome                    0                      0.000000
# incidenceRate                0                      0.000000
# TARGET_deathRate             0                      0.000000
# avgDeathsPerYear             0                      0.000000
# AvgHouseholdSize             0                      0.000000
# PctHS18_24                   0                      0.000000
# PctNoHS18_24                 0                      0.000000
# PctMarriedHouseholds         0                      0.000000
# PctBachDeg18_24              0                      0.000000
# PctHS25_Over                 0                      0.000000
# PctBachDeg25_Over            0                      0.000000
# PctUnemployed16_Over         0                      0.000000
# PctPrivateCoverage           0                      0.000000
# PctEmpPrivCoverage           0                      0.000000
# PctPublicCoverage            0                      0.000000
# PctPublicCoverageAlone       0                      0.000000
# PctWhite                     0                      0.000000
# PctBlack                     0                      0.000000
# PctAsian                     0                      0.000000
# PctOtherRace                 0                      0.000000
# avgAnnCount                  0                      0.000000

# %% [markdown]
# #### There are missing values in three variables. Lets try to interpret the missing values

# %%
# set the figure size
plt.figure(figsize=(15, 8))

# plot heatmap to check null values
# isnull(): returns 'True' for a missing value
# cbar: specifies whether to draw a colorbar; draws the colorbar for 'True' 
sns.heatmap(df.isnull(), cbar=False)

# display the plot
plt.show()

# %%
#Filling the missing values using mean, because it is numeric column
df.fillna(df['PctSomeCol18_24'].mean(), inplace=True)

# %%
df.fillna(df['PctPrivateCoverageAlone'].mean(), inplace=True)

# %%
df.fillna(df['PctEmployed16_Over'].mean(), inplace=True)

# %%
#Rechecking the missing values
# set the figure size
plt.figure(figsize=(15, 8))

# plot heatmap to check null values
# isnull(): returns 'True' for a missing value
# cbar: specifies whether to draw a colorbar; draws the colorbar for 'True' 
sns.heatmap(df.isnull(), cbar=False)

# display the plot
plt.show()

# %%
# select the numerical features in the dataset using 'select_dtypes()'
# select_dtypes(include=np.number): considers the numeric variables
df_numeric_features = df.select_dtypes(include=np.number)

# print the names of the numeric variables 
df_numeric_features.columns
# Out:
# Index(['avgAnnCount', 'avgDeathsPerYear', 'TARGET_deathRate', 'incidenceRate',
#        'medIncome', 'popEst2015', 'povertyPercent', 'studyPerCap', 'MedianAge',
#        'MedianAgeMale', 'MedianAgeFemale', 'AvgHouseholdSize',
#        'PercentMarried', 'PctNoHS18_24', 'PctHS18_24', 'PctSomeCol18_24',
#        'PctBachDeg18_24', 'PctHS25_Over', 'PctBachDeg25_Over',
#        'PctEmployed16_Over', 'PctUnemployed16_Over', 'PctPrivateCoverage',
#        'PctPrivateCoverageAlone', 'PctEmpPrivCoverage', 'PctPublicCoverage',
#        'PctPublicCoverageAlone', 'PctWhite', 'PctBlack', 'PctAsian',
#        'PctOtherRace', 'PctMarriedHouseholds', 'BirthRate'],
#       dtype='object')

# %%
# generate the correlation matrix
corr =  df_numeric_features.corr()

# print the correlation matrix
corr
# Out:
#                          avgAnnCount  avgDeathsPerYear  TARGET_deathRate  \
# avgAnnCount                 1.000000          0.939408         -0.143532
# avgDeathsPerYear            0.939408          1.000000         -0.090715
# TARGET_deathRate           -0.143532         -0.090715          1.000000
# incidenceRate               0.073553          0.062690          0.449432
# medIncome                   0.269145          0.223207         -0.428615
# popEst2015                  0.926894          0.977634         -0.120073
# povertyPercent             -0.135694         -0.066918          0.429389
# studyPerCap                 0.082071          0.063488         -0.022285
# MedianAge                  -0.024098         -0.024599          0.004375
# MedianAgeMale              -0.124969         -0.148487         -0.021929
# MedianAgeFemale            -0.122844         -0.144069          0.012048
# AvgHouseholdSize            0.064788          0.086161         -0.036905
# PercentMarried             -0.106108         -0.181029         -0.266820
# PctNoHS18_24               -0.143327         -0.136794          0.088463
# PctHS18_24                 -0.182054         -0.151418          0.261976
# PctSomeCol18_24             0.070159          0.063322         -0.094765
# PctBachDeg18_24             0.284176          0.259761         -0.287817
# PctHS25_Over               -0.311375         -0.295929          0.404589
# PctBachDeg25_Over           0.321021          0.293210         -0.485477
# PctEmployed16_Over          0.191672          0.122171         -0.376022
# PctUnemployed16_Over       -0.009016          0.069701          0.378412
# PctPrivateCoverage          0.132244          0.056183         -0.386066
# PctPrivateCoverageAlone     0.158048          0.106409         -0.305253
# PctEmpPrivCoverage          0.202349          0.160124         -0.267399
# PctPublicCoverage          -0.173548         -0.131687          0.404572
# PctPublicCoverageAlone     -0.093699         -0.027338          0.449358
# PctWhite                   -0.136501         -0.187159         -0.177400
# PctBlack                    0.031376          0.084607          0.257024
# PctAsian                    0.435071          0.443074         -0.186331
# PctOtherRace                0.209184          0.215149         -0.189894
# PctMarriedHouseholds       -0.106221         -0.160266         -0.293325
# BirthRate                  -0.034508         -0.074420         -0.087407
#
#                          incidenceRate  medIncome  popEst2015  povertyPercent  \
# avgAnnCount                   0.073553   0.269145    0.926894       -0.135694
# avgDeathsPerYear              0.062690   0.223207    0.977634       -0.066918
# TARGET_deathRate              0.449432  -0.428615   -0.120073        0.429389
# incidenceRate                 1.000000  -0.001036    0.026912        0.009046
# medIncome                    -0.001036   1.000000    0.235523       -0.788965
# popEst2015                    0.026912   0.235523    1.000000       -0.065299
# povertyPercent                0.009046  -0.788965   -0.065299        1.000000
# studyPerCap                   0.077283   0.044003    0.055722       -0.055652
# MedianAge                     0.018089  -0.013288   -0.025219       -0.029280
# MedianAgeMale                -0.014733  -0.091663   -0.176608       -0.214001
# MedianAgeFemale              -0.009106  -0.153278   -0.177932       -0.148164
# AvgHouseholdSize             -0.118400   0.112065    0.109940        0.074308
# PercentMarried               -0.119524   0.355123   -0.160463       -0.642857
# PctNoHS18_24                 -0.170762  -0.289383   -0.126582        0.288106
# PctHS18_24                    0.022644  -0.190006   -0.151821        0.094211
# PctSomeCol18_24               0.038442   0.101864    0.065207       -0.079355
# PctBachDeg18_24               0.046835   0.492810    0.248375       -0.387122
# PctHS25_Over                  0.121725  -0.471348   -0.311849        0.194361
# PctBachDeg25_Over            -0.038177   0.704928    0.297463       -0.531600
# PctEmployed16_Over           -0.003664   0.630119    0.136180       -0.670239
# PctUnemployed16_Over          0.099979  -0.453108    0.050768        0.655148
# PctPrivateCoverage            0.105174   0.724175    0.052677       -0.822534
# PctPrivateCoverageAlone       0.097675   0.669381    0.115608       -0.645117
# PctEmpPrivCoverage            0.149825   0.747294    0.158650       -0.683100
# PctPublicCoverage             0.046109  -0.754822   -0.160066        0.651162
# PctPublicCoverageAlone        0.040812  -0.719756   -0.041469        0.798642
# PctWhite                     -0.014510   0.167225   -0.190095       -0.509433
# PctBlack                      0.113489  -0.270232    0.073044        0.511530
# PctAsian                     -0.008123   0.425844    0.464168       -0.157289
# PctOtherRace                 -0.208748   0.083635    0.241468        0.047096
# PctMarriedHouseholds         -0.152176   0.446083   -0.127979       -0.604953
# BirthRate                    -0.118181  -0.010195   -0.057740       -0.012283
#
#                          studyPerCap  MedianAge  MedianAgeMale  ...  \
# avgAnnCount                 0.082071  -0.024098      -0.124969  ...
# avgDeathsPerYear            0.063488  -0.024599      -0.148487  ...
# TARGET_deathRate           -0.022285   0.004375      -0.021929  ...
# incidenceRate               0.077283   0.018089      -0.014733  ...
# medIncome                   0.044003  -0.013288      -0.091663  ...
# popEst2015                  0.055722  -0.025219      -0.176608  ...
# povertyPercent             -0.055652  -0.029280      -0.214001  ...
# studyPerCap                 1.000000  -0.026030      -0.036647  ...
# MedianAge                  -0.026030   1.000000       0.129119  ...
# MedianAgeMale              -0.036647   0.129119       1.000000  ...
# MedianAgeFemale            -0.030577   0.124678       0.933696  ...
# AvgHouseholdSize           -0.004071  -0.031944      -0.343189  ...
# PercentMarried             -0.038143   0.046372       0.449986  ...
# PctNoHS18_24               -0.090387   0.006178       0.100486  ...
# PctHS18_24                 -0.057035   0.050574       0.241310  ...
# PctSomeCol18_24             0.032604  -0.009180      -0.134864  ...
# PctBachDeg18_24             0.063819  -0.016909      -0.034135  ...
# PctHS25_Over               -0.085128   0.036587       0.318277  ...
# PctBachDeg25_Over           0.108594  -0.020352      -0.131599  ...
# PctEmployed16_Over          0.088950  -0.027645      -0.144326  ...
# PctUnemployed16_Over       -0.031957   0.018590      -0.142737  ...
# PctPrivateCoverage          0.092545   0.004665       0.082232  ...
# PctPrivateCoverageAlone     0.069052  -0.022597      -0.141406  ...
# PctEmpPrivCoverage          0.100063  -0.036926      -0.208664  ...
# PctPublicCoverage          -0.051497   0.049060       0.398967  ...
# PctPublicCoverageAlone     -0.055512  -0.003298       0.002479  ...
# PctWhite                    0.023291   0.035009       0.398044  ...
# PctBlack                   -0.019761  -0.017173      -0.242748  ...
# PctAsian                    0.062543  -0.038424      -0.238322  ...
# PctOtherRace               -0.015247  -0.030277      -0.266655  ...
# PctMarriedHouseholds       -0.051736   0.014504       0.222278  ...
# BirthRate                   0.010676  -0.008276      -0.104105  ...
#
#                          PctPrivateCoverageAlone  PctEmpPrivCoverage  \
# avgAnnCount                             0.158048            0.202349
# avgDeathsPerYear                        0.106409            0.160124
# TARGET_deathRate                       -0.305253           -0.267399
# incidenceRate                           0.097675            0.149825
# medIncome                               0.669381            0.747294
# popEst2015                              0.115608            0.158650
# povertyPercent                         -0.645117           -0.683100
# studyPerCap                             0.069052            0.100063
# MedianAge                              -0.022597           -0.036926
# MedianAgeMale                          -0.141406           -0.208664
# MedianAgeFemale                        -0.180125           -0.252221
# AvgHouseholdSize                       -0.004797            0.011111
# PercentMarried                          0.282342            0.232899
# PctNoHS18_24                           -0.390719           -0.429994
# PctHS18_24                             -0.244294           -0.244494
# PctSomeCol18_24                         0.171641            0.184362
# PctBachDeg18_24                         0.421281            0.450996
# PctHS25_Over                           -0.247602           -0.222803
# PctBachDeg25_Over                       0.542366            0.539084
# PctEmployed16_Over                      0.598767            0.638854
# PctUnemployed16_Over                   -0.494254           -0.474745
# PctPrivateCoverage                      0.790890            0.827459
# PctPrivateCoverageAlone                 1.000000            0.793440
# PctEmpPrivCoverage                      0.793440            1.000000
# PctPublicCoverage                      -0.731029           -0.778315
# PctPublicCoverageAlone                 -0.726893           -0.728823
# PctWhite                                0.262996            0.269815
# PctBlack                               -0.231828           -0.237388
# PctAsian                                0.236325            0.282484
# PctOtherRace                           -0.077868           -0.064226
# PctMarriedHouseholds                    0.331681            0.322569
# BirthRate                              -0.032748           -0.093878
#
#                          PctPublicCoverage  PctPublicCoverageAlone  PctWhite  \
# avgAnnCount                      -0.173548               -0.093699 -0.136501
# avgDeathsPerYear                 -0.131687               -0.027338 -0.187159
# TARGET_deathRate                  0.404572                0.449358 -0.177400
# incidenceRate                     0.046109                0.040812 -0.014510
# medIncome                        -0.754822               -0.719756  0.167225
# popEst2015                       -0.160066               -0.041469 -0.190095
# povertyPercent                    0.651162                0.798642 -0.509433
# studyPerCap                      -0.051497               -0.055512  0.023291
# MedianAge                         0.049060               -0.003298  0.035009
# MedianAgeMale                     0.398967                0.002479  0.398044
# MedianAgeFemale                   0.455496                0.047659  0.339804
# AvgHouseholdSize                 -0.134812                0.061115 -0.188446
# PercentMarried                   -0.246972               -0.459990  0.677420
# PctNoHS18_24                      0.318540                0.327270 -0.157282
# PctHS18_24                        0.278220                0.234124  0.045306
# PctSomeCol18_24                  -0.172834               -0.155653  0.047537
# PctBachDeg18_24                  -0.422470               -0.421805  0.069133
# PctHS25_Over                      0.427974                0.297143  0.188045
# PctBachDeg25_Over                -0.636095               -0.605760  0.048652
# PctEmployed16_Over               -0.696912               -0.646345  0.244414
# PctUnemployed16_Over              0.529821                0.655366 -0.501755
# PctPrivateCoverage               -0.720012               -0.886234  0.429031
# PctPrivateCoverageAlone          -0.731029               -0.726893  0.262996
# PctEmpPrivCoverage               -0.778315               -0.728823  0.269815
# PctPublicCoverage                 1.000000                0.865833 -0.133705
# PctPublicCoverageAlone            0.865833                1.000000 -0.361026
# PctWhite                         -0.133705               -0.361026  1.000000
# PctBlack                          0.195597                0.330110 -0.828459
# PctAsian                         -0.305625               -0.181380 -0.265676
# PctOtherRace                     -0.078708                0.083755 -0.233692
# PctMarriedHouseholds             -0.362171               -0.473994  0.596771
# BirthRate                        -0.030531               -0.004753 -0.008958
#
#                          PctBlack  PctAsian  PctOtherRace  \
# avgAnnCount              0.031376  0.435071      0.209184
# avgDeathsPerYear         0.084607  0.443074      0.215149
# TARGET_deathRate         0.257024 -0.186331     -0.189894
# incidenceRate            0.113489 -0.008123     -0.208748
# medIncome               -0.270232  0.425844      0.083635
# popEst2015               0.073044  0.464168      0.241468
# povertyPercent           0.511530 -0.157289      0.047096
# studyPerCap             -0.019761  0.062543     -0.015247
# MedianAge               -0.017173 -0.038424     -0.030277
# MedianAgeMale           -0.242748 -0.238322     -0.266655
# MedianAgeFemale         -0.156728 -0.258748     -0.274120
# AvgHouseholdSize         0.030278  0.131535      0.229440
# PercentMarried          -0.622357 -0.148691     -0.104669
# PctNoHS18_24             0.116805 -0.217535      0.126256
# PctHS18_24              -0.024868 -0.199770     -0.060415
# PctSomeCol18_24         -0.039761  0.100835     -0.019305
# PctBachDeg18_24         -0.093614  0.345883      0.006547
# PctHS25_Over            -0.024445 -0.436561     -0.285611
# PctBachDeg25_Over       -0.146409  0.437963      0.039075
# PctEmployed16_Over      -0.307058  0.221841      0.054738
# PctUnemployed16_Over     0.469273 -0.022020      0.028463
# PctPrivateCoverage      -0.345172  0.189332     -0.176300
# PctPrivateCoverageAlone -0.231828  0.236325     -0.077868
# PctEmpPrivCoverage      -0.237388  0.282484     -0.064226
# PctPublicCoverage        0.195597 -0.305625     -0.078708
# PctPublicCoverageAlone   0.330110 -0.181380      0.083755
# PctWhite                -0.828459 -0.265676     -0.233692
# PctBlack                 1.000000  0.016583     -0.023001
# PctAsian                 0.016583  1.000000      0.200781
# PctOtherRace            -0.023001  0.200781      1.000000
# PctMarriedHouseholds    -0.573592 -0.086602     -0.027352
# BirthRate               -0.067805 -0.061947      0.059829
#
#                          PctMarriedHouseholds  BirthRate
# avgAnnCount                         -0.106221  -0.034508
# avgDeathsPerYear                    -0.160266  -0.074420
# TARGET_deathRate                    -0.293325  -0.087407
# incidenceRate                       -0.152176  -0.118181
# medIncome                            0.446083  -0.010195
# popEst2015                          -0.127979  -0.057740
# povertyPercent                      -0.604953  -0.012283
# studyPerCap                         -0.051736   0.010676
# MedianAge                            0.014504  -0.008276
# MedianAgeMale                        0.222278  -0.104105
# MedianAgeFemale                      0.161507  -0.098813
# AvgHouseholdSize                     0.091450   0.075918
# PercentMarried                       0.870261   0.141404
# PctNoHS18_24                         0.005340   0.125895
# PctHS18_24                           0.120040   0.058227
# PctSomeCol18_24                     -0.029213  -0.029798
# PctBachDeg18_24                     -0.000104  -0.125073
# PctHS25_Over                         0.062176   0.016600
# PctBachDeg25_Over                    0.098134  -0.087940
# PctEmployed16_Over                   0.283420   0.073663
# PctUnemployed16_Over                -0.469609  -0.067906
# PctPrivateCoverage                   0.434640  -0.040437
# PctPrivateCoverageAlone              0.331681  -0.032748
# PctEmpPrivCoverage                   0.322569  -0.093878
# PctPublicCoverage                   -0.362171  -0.030531
# PctPublicCoverageAlone              -0.473994  -0.004753
# PctWhite                             0.596771  -0.008958
# PctBlack                            -0.573592  -0.067805
# PctAsian                            -0.086602  -0.061947
# PctOtherRace                        -0.027352   0.059829
# PctMarriedHouseholds                 1.000000   0.102263
# BirthRate                            0.102263   1.000000
#
# [32 rows x 32 columns]

# %% [markdown]
# #### Some of the variables have high correlation, and some have negative correlation.

# %%
plt.figure(figsize=(16,8))
sns.boxplot(data=df)

# %%
#Two variables have outliars, lets remove them
q1=df.quantile(.25)
q3=df.quantile(.75)

IQR = q3-q1
LL=q1-1.5*IQR
UL=q3+1.5*IQR

df=df[~((df< LL) | (df>UL)).any(axis=1)]

# %%
df.columns
# Out:
# Index(['avgAnnCount', 'avgDeathsPerYear', 'TARGET_deathRate', 'incidenceRate',
#        'medIncome', 'popEst2015', 'povertyPercent', 'studyPerCap', 'binnedInc',
#        'MedianAge', 'MedianAgeMale', 'MedianAgeFemale', 'Geography',
#        'AvgHouseholdSize', 'PercentMarried', 'PctNoHS18_24', 'PctHS18_24',
#        'PctSomeCol18_24', 'PctBachDeg18_24', 'PctHS25_Over',
#        'PctBachDeg25_Over', 'PctEmployed16_Over', 'PctUnemployed16_Over',
#        'PctPrivateCoverage', 'PctPrivateCoverageAlone', 'PctEmpPrivCoverage',
#        'PctPublicCoverage', 'PctPublicCoverageAlone', 'PctWhite', 'PctBlack',
#        'PctAsian', 'PctOtherRace', 'PctMarriedHouseholds', 'BirthRate'],
#       dtype='object')

# %%
#Lets split the data and build the model
from sklearn.model_selection import train_test_split

X=df.drop('TARGET_deathRate',axis =1)
y=df['TARGET_deathRate']

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size =0.3,random_state=2)

# %%
print('Percentage of X_train: ',len(X_train)/len(df) *100)
print('Percentage of X_test: ',len(X_test)/len(df) *100)
print('Percentage of y_train: ',len(y_train)/len(df) *100)
print('Percentage of y_test: ',len(y_test)/len(df) *100)
# Out:
# Percentage of X_train:  69.96735582154517
# Percentage of X_test:  30.03264417845484
# Percentage of y_train:  69.96735582154517
# Percentage of y_test:  30.03264417845484

# %%
df_num=df.select_dtypes(include=np.number)

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
df_num_ss=ss.fit_transform(df_num)
df_ss=pd.DataFrame(df_num_ss,columns = df_num.columns)

# %%
df=df.dropna()

# %%
X= df_ss.drop('TARGET_deathRate',axis=1)
y=df_ss['TARGET_deathRate']

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=2)

# %%
#Lets try the Linear Regression model

from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
y_test_pred =lr.predict(X_test)
y_train_pred = lr.predict(X_train)

r2_test=r2_score(y_test,y_test_pred)
r2_train=r2_score(y_train,y_train_pred)

rsme_test =np.sqrt(mean_squared_error(y_test,y_test_pred))
rsme_train =np.sqrt(mean_squared_error(y_train,y_train_pred))

mape_test=mean_absolute_error(y_test,y_test_pred) *100
mape_train=mean_absolute_error(y_train,y_train_pred)*100

print('r2_train: ',r2_train,  'r2_test: ',r2_test)
print('rsme_train: ',rsme_train , 'rsme_test: ',rsme_test)
print('mape_train: ',mape_train,'mape_test: ',mape_test)
# Out:
# r2_train:  0.658655076026911 r2_test:  0.6317803645036277
# rsme_train:  0.5725413937242564 rsme_test:  0.6342316903169141
# mape_train:  43.57585693499577 mape_test:  46.51407757142238

# %%
# building a full model with an interaction term using OLS()
linreg_with_interaction = sm.OLS(y_train, X_train).fit()

# print the summary output
print(linreg_with_interaction.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       TARGET_deathRate   R-squared:                       0.659
# Model:                            OLS   Adj. R-squared:                  0.643
# Method:                 Least Squares   F-statistic:                     40.79
# Date:                Thu, 30 Dec 2021   Prob (F-statistic):          6.69e-123
# Time:                        13:32:19   Log-Likelihood:                -553.80
# No. Observations:                 643   AIC:                             1168.
# Df Residuals:                     613   BIC:                             1302.
# Df Model:                          29
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# avgAnnCount                -3.5579      0.236    -15.083      0.000      -4.021      -3.095
# avgDeathsPerYear            3.1637      0.182     17.358      0.000       2.806       3.522
# incidenceRate               0.4979      0.031     16.148      0.000       0.437       0.558
# medIncome                   0.0750      0.066      1.138      0.256      -0.054       0.204
# popEst2015                  0.3906      0.139      2.816      0.005       0.118       0.663
# povertyPercent              0.0709      0.067      1.060      0.289      -0.060       0.202
# studyPerCap                -0.0021      0.025     -0.082      0.934      -0.051       0.047
# MedianAge                   0.0641      0.346      0.185      0.853      -0.616       0.744
# MedianAgeMale              -0.0514      0.196     -0.263      0.793      -0.436       0.333
# MedianAgeFemale            -0.0907      0.185     -0.491      0.624      -0.454       0.272
# AvgHouseholdSize           -0.0030      0.054     -0.056      0.955      -0.108       0.102
# PercentMarried              0.0125      0.064      0.194      0.846      -0.113       0.138
# PctNoHS18_24               -0.0313      0.028     -1.107      0.269      -0.087       0.024
# PctHS18_24                  0.0443      0.028      1.574      0.116      -0.011       0.100
# PctSomeCol18_24           -3.7e+11   3.28e+12     -0.113      0.910   -6.81e+12    6.07e+12
# PctBachDeg18_24            -0.0016      0.030     -0.052      0.958      -0.060       0.057
# PctHS25_Over               -0.0185      0.041     -0.457      0.648      -0.098       0.061
# PctBachDeg25_Over          -0.1344      0.048     -2.790      0.005      -0.229      -0.040
# PctEmployed16_Over         -0.0387      0.038     -1.018      0.309      -0.113       0.036
# PctUnemployed16_Over        0.0287      0.037      0.779      0.436      -0.044       0.101
# PctPrivateCoverage         -0.2624      0.095     -2.775      0.006      -0.448      -0.077
# PctPrivateCoverageAlone     0.0348      0.046      0.758      0.449      -0.055       0.125
# PctEmpPrivCoverage          0.0783      0.063      1.249      0.212      -0.045       0.201
# PctPublicCoverage           0.0670      0.111      0.605      0.545      -0.150       0.285
# PctPublicCoverageAlone     -0.0253      0.105     -0.240      0.811      -0.232       0.182
# PctWhite                   -0.0900      0.041     -2.199      0.028      -0.170      -0.010
# PctBlack                   -0.0658      0.038     -1.742      0.082      -0.140       0.008
# PctAsian                   -0.0113      0.031     -0.367      0.714      -0.072       0.049
# PctOtherRace               -0.1163      0.028     -4.086      0.000      -0.172      -0.060
# PctMarriedHouseholds       -0.0236      0.061     -0.384      0.701      -0.144       0.097
# BirthRate                  -0.0518      0.025     -2.070      0.039      -0.101      -0.003
# ==============================================================================
# Omnibus:                       11.062   Durbin-Watson:                   2.012
# Prob(Omnibus):                  0.004   Jarque-Bera (JB):               18.522
# Skew:                           0.042   Prob(JB):                     9.51e-05
# Kurtosis:                       3.827   Cond. No.                     4.01e+14
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.2e-26. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# ### Lets try to improve the model

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import ElasticNet

# 'Statsmodels' is used to build and analyze various statistical models
import statsmodels
import statsmodels.api as sm
import statsmodels.stats.api as sms
from statsmodels.tools.eval_measures import rmse
from statsmodels.compat import lzip
from statsmodels.graphics.gofplots import ProbPlot

# 'SciPy' is used to perform scientific computations
from scipy.stats import f_oneway
from scipy.stats import jarque_bera
from scipy import stats

# %%
# create list of variable names
col = list(X_train.columns)

# add 'Sum of square of Residuals' to the list
col.append('ssr')

# add 'R squared' to the list
col.append('R squared')

# add 'Adj. R squared' to the list
col.append('Adj. R squared')

# add 'Root mean Squared Error' to the list
col.append('RMSE')

# %%
# build a OLS model using OLS()
ridge_regression = sm.OLS(y_train, X_train)

# the fitted ridge model
results_fu = ridge_regression.fit()

# %%
# create an empty list
frames = []

# a 'for' loop for values of alpha in a given range
# the loop prepares a table of regression coefficients for different values of alpha
# the values of alpha are given to be 0.0001, 0.1001, 0.2001, 0.3001, 0.4001, 0.5001 and 10.0001
for n in np.arange(0.0001,10.1, 0.1).tolist():
    
    # fit a rigde regression to the linear model built using OLS
    # L1_wt=0: conducts ridge regression
    # alpha: specifies the alpha value
    # start_params: starting values for patameters
    results_fr = ridge_regression.fit_regularized(L1_wt=0, alpha=n, start_params=results_fu.params)
    
    # fit the model
    # model: specifies the regression model
    # params: specifies the estimated parameters
    # normalized_cov_params: specifies the normalized covariance parameters
    results_fr_fit = sm.regression.linear_model.OLSResults(model=ridge_regression, 
                                             params=results_fr.params, 
                                             normalized_cov_params=ridge_regression.normalized_cov_params)
    
    # compute the rmse
    # calling the test data
    results_fr_fit_predictions = results_fr_fit.predict(X_test)
    
    # obtain the rmse
    results_fr_fit_rmse = rmse(y_test, results_fr_fit_predictions)    
  
    # compile the necessary metrics used for comparing the models
    list_metric = [results_fr_fit.ssr, results_fr_fit.rsquared, results_fr_fit.rsquared_adj, results_fr_fit_rmse]
    
    # append the empty list 
    frames.append(np.append(results_fr.params, list_metric))
    
    # converting the list to a dataframe.
    df_params = pd.DataFrame(frames, columns= col)

# add column names to the dataframe  
df_params.index=np.arange(0.0001, 10.1, 0.1).tolist()

# add the first column name alpha to the data frame. 
# this column will hold the regularization parameter value which can be anything from zero to any positive number
df_params.index.name = 'alpha*'

# display the output
df_params
# Out:
#          avgAnnCount  avgDeathsPerYear  incidenceRate  medIncome  popEst2015  \
# alpha*
# 0.0001     -3.498555          3.120766       0.494159   0.074234    0.374562
# 0.1001     -0.166976          0.295369       0.269146  -0.025516   -0.084526
# 0.2001     -0.075704          0.167559       0.241163  -0.039512   -0.047445
# 0.3001     -0.044935          0.120234       0.220481  -0.044714   -0.031541
# 0.4001     -0.029648          0.095420       0.203747  -0.047087   -0.022685
# ...              ...               ...            ...        ...         ...
# 9.6001      0.004282          0.010734       0.029393  -0.025211    0.002810
# 9.7001      0.004259          0.010651       0.029128  -0.025067    0.002796
# 9.8001      0.004236          0.010570       0.028869  -0.024924    0.002782
# 9.9001      0.004213          0.010490       0.028614  -0.024783    0.002768
# 10.0001     0.004190          0.010412       0.028363  -0.024644    0.002754
#
#          povertyPercent  studyPerCap  MedianAge  MedianAgeMale  \
# alpha*
# 0.0001         0.072528    -0.002439   0.059685      -0.050818
# 0.1001         0.116269    -0.017543  -0.039166      -0.058945
# 0.2001         0.100653    -0.015191  -0.040991      -0.051766
# 0.3001         0.091551    -0.013614  -0.041051      -0.048002
# 0.4001         0.085447    -0.012436  -0.040469      -0.045378
# ...                 ...          ...        ...            ...
# 9.6001         0.029325    -0.000938  -0.010717      -0.010574
# 9.7001         0.029149    -0.000924  -0.010632      -0.010489
# 9.8001         0.028975    -0.000911  -0.010547      -0.010405
# 9.9001         0.028804    -0.000898  -0.010464      -0.010323
# 10.0001        0.028634    -0.000885  -0.010383      -0.010242
#
#          MedianAgeFemale  ...  PctWhite  PctBlack  PctAsian  PctOtherRace  \
# alpha*                    ...
# 0.0001         -0.088266  ... -0.091128 -0.066503 -0.011368     -0.117010
# 0.1001         -0.029689  ... -0.116693 -0.077071 -0.033593     -0.133359
# 0.2001         -0.036440  ... -0.090109 -0.053395 -0.034159     -0.119249
# 0.3001         -0.038606  ... -0.072928 -0.038761 -0.033237     -0.108813
# 0.4001         -0.039066  ... -0.061198 -0.029100 -0.032034     -0.100602
# ...                  ...  ...       ...       ...       ...           ...
# 9.6001         -0.010577  ... -0.008681  0.005773 -0.006930     -0.014397
# 9.7001         -0.010491  ... -0.008632  0.005753 -0.006874     -0.014262
# 9.8001         -0.010406  ... -0.008582  0.005733 -0.006819     -0.014129
# 9.9001         -0.010323  ... -0.008534  0.005713 -0.006765     -0.013999
# 10.0001        -0.010241  ... -0.008486  0.005693 -0.006712     -0.013871
#
#          PctMarriedHouseholds  BirthRate         ssr  R squared  \
# alpha*
# 0.0001              -0.024430  -0.051753  210.804418   0.658612
# 0.1001              -0.044784  -0.035075  301.945712   0.511013
# 0.2001              -0.036049  -0.028880  313.832487   0.491763
# 0.3001              -0.031658  -0.025016  320.802028   0.480476
# 0.4001              -0.029128  -0.022324  326.111849   0.471877
# ...                       ...        ...         ...        ...
# 9.6001              -0.013389  -0.003786  465.855405   0.245568
# 9.7001              -0.013318  -0.003756  466.591325   0.244377
# 9.8001              -0.013247  -0.003727  467.320055   0.243197
# 9.9001              -0.013177  -0.003698  468.041705   0.242028
# 10.0001             -0.013108  -0.003670  468.756380   0.240870
#
#          Adj. R squared      RMSE
# alpha*
# 0.0001         0.642461  0.634848
# 0.1001         0.487880  0.769353
# 0.2001         0.467719  0.780637
# 0.3001         0.455898  0.786922
# 0.4001         0.446892  0.791831
# ...                 ...       ...
# 9.6001         0.209878  0.927336
# 9.7001         0.208629  0.927967
# 9.8001         0.207393  0.928591
# 9.9001         0.206169  0.929209
# 10.0001        0.204957  0.929819
#
# [101 rows x 35 columns]

# %%
# call the first two rows and last two rows
df_params.iloc[[0,1,-2,-1]]
# Out:
#          avgAnnCount  avgDeathsPerYear  incidenceRate  medIncome  popEst2015  \
# alpha*
# 0.0001     -3.498555          3.120766       0.494159   0.074234    0.374562
# 0.1001     -0.166976          0.295369       0.269146  -0.025516   -0.084526
# 9.9001      0.004213          0.010490       0.028614  -0.024783    0.002768
# 10.0001     0.004190          0.010412       0.028363  -0.024644    0.002754
#
#          povertyPercent  studyPerCap  MedianAge  MedianAgeMale  \
# alpha*
# 0.0001         0.072528    -0.002439   0.059685      -0.050818
# 0.1001         0.116269    -0.017543  -0.039166      -0.058945
# 9.9001         0.028804    -0.000898  -0.010464      -0.010323
# 10.0001        0.028634    -0.000885  -0.010383      -0.010242
#
#          MedianAgeFemale  ...  PctWhite  PctBlack  PctAsian  PctOtherRace  \
# alpha*                    ...
# 0.0001         -0.088266  ... -0.091128 -0.066503 -0.011368     -0.117010
# 0.1001         -0.029689  ... -0.116693 -0.077071 -0.033593     -0.133359
# 9.9001         -0.010323  ... -0.008534  0.005713 -0.006765     -0.013999
# 10.0001        -0.010241  ... -0.008486  0.005693 -0.006712     -0.013871
#
#          PctMarriedHouseholds  BirthRate         ssr  R squared  \
# alpha*
# 0.0001              -0.024430  -0.051753  210.804418   0.658612
# 0.1001              -0.044784  -0.035075  301.945712   0.511013
# 9.9001              -0.013177  -0.003698  468.041705   0.242028
# 10.0001             -0.013108  -0.003670  468.756380   0.240870
#
#          Adj. R squared      RMSE
# alpha*
# 0.0001         0.642461  0.634848
# 0.1001         0.487880  0.769353
# 9.9001         0.206169  0.929209
# 10.0001        0.204957  0.929819
#
# [4 rows x 35 columns]

# %%
alpha = df_params.RMSE[df_params.RMSE == df_params.loc[:,'RMSE'].min()].index.tolist()

# print the conclusion
print('The required alpha is %.4f ' % (alpha[0]))
# Out:
# The required alpha is 0.0001

# %%
# check for zeros in the above coefficients table
# axis=1: specifies that the apply() is to be applies column wise
df_params.apply(lambda x: sum(x.values==0),axis=1)
# Out:
# alpha*
# 0.0001     0
# 0.1001     0
# 0.2001     0
# 0.3001     0
# 0.4001     0
#           ..
# 9.6001     0
# 9.7001     0
# 9.8001     0
# 9.9001     0
# 10.0001    0
# Length: 101, dtype: int64

# %%
# build a ridge model for the desired alpha 
# L1_wt=0: conducts ridge regression
# alpha: specifies the alpha value
# start_params: starting values for patameters
results_fr = ridge_regression.fit_regularized(L1_wt=0, alpha=0.0001, start_params=results_fu.params)

# fit the model 
# model: specifies the regression model
# params: specifies the estimated parameters
# normalized_cov_params: specifies the normalized covariance parameters
ridge_regression_best = sm.regression.linear_model.OLSResults(model = ridge_regression, 
                                        params=results_fr.params, 
                                        normalized_cov_params=ridge_regression.normalized_cov_params)

# print the summary output 
print (ridge_regression_best.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       TARGET_deathRate   R-squared:                       0.659
# Model:                            OLS   Adj. R-squared:                  0.642
# Method:                 Least Squares   F-statistic:                     40.78
# Date:                Thu, 30 Dec 2021   Prob (F-statistic):          6.95e-123
# Time:                        13:32:23   Log-Likelihood:                -553.84
# No. Observations:                 643   AIC:                             1168.
# Df Residuals:                     613   BIC:                             1302.
# Df Model:                          29
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# avgAnnCount                -3.4986      0.236    -14.831      0.000      -3.962      -3.035
# avgDeathsPerYear            3.1208      0.182     17.122      0.000       2.763       3.479
# incidenceRate               0.4942      0.031     16.027      0.000       0.434       0.555
# medIncome                   0.0742      0.066      1.127      0.260      -0.055       0.204
# popEst2015                  0.3746      0.139      2.700      0.007       0.102       0.647
# povertyPercent              0.0725      0.067      1.085      0.278      -0.059       0.204
# studyPerCap                -0.0024      0.025     -0.097      0.923      -0.052       0.047
# MedianAge                   0.0597      0.346      0.172      0.863      -0.621       0.740
# MedianAgeMale              -0.0508      0.196     -0.260      0.795      -0.435       0.333
# MedianAgeFemale            -0.0883      0.185     -0.477      0.633      -0.451       0.275
# AvgHouseholdSize           -0.0023      0.054     -0.042      0.966      -0.108       0.103
# PercentMarried              0.0140      0.064      0.218      0.827      -0.112       0.140
# PctNoHS18_24               -0.0314      0.028     -1.111      0.267      -0.087       0.024
# PctHS18_24                  0.0451      0.028      1.604      0.109      -0.010       0.100
# PctSomeCol18_24         -1.758e-13   3.28e+12  -5.36e-26      1.000   -6.44e+12    6.44e+12
# PctBachDeg18_24            -0.0017      0.030     -0.056      0.956      -0.060       0.057
# PctHS25_Over               -0.0182      0.041     -0.449      0.653      -0.098       0.061
# PctBachDeg25_Over          -0.1356      0.048     -2.814      0.005      -0.230      -0.041
# PctEmployed16_Over         -0.0389      0.038     -1.025      0.306      -0.114       0.036
# PctUnemployed16_Over        0.0285      0.037      0.773      0.440      -0.044       0.101
# PctPrivateCoverage         -0.2619      0.095     -2.769      0.006      -0.448      -0.076
# PctPrivateCoverageAlone     0.0351      0.046      0.764      0.445      -0.055       0.125
# PctEmpPrivCoverage          0.0778      0.063      1.241      0.215      -0.045       0.201
# PctPublicCoverage           0.0648      0.111      0.585      0.559      -0.153       0.282
# PctPublicCoverageAlone     -0.0244      0.105     -0.231      0.817      -0.232       0.183
# PctWhite                   -0.0911      0.041     -2.226      0.026      -0.172      -0.011
# PctBlack                   -0.0665      0.038     -1.760      0.079      -0.141       0.008
# PctAsian                   -0.0114      0.031     -0.370      0.712      -0.072       0.049
# PctOtherRace               -0.1170      0.028     -4.112      0.000      -0.173      -0.061
# PctMarriedHouseholds       -0.0244      0.061     -0.398      0.691      -0.145       0.096
# BirthRate                  -0.0518      0.025     -2.066      0.039      -0.101      -0.003
# ==============================================================================
# Omnibus:                       10.896   Durbin-Watson:                   2.011
# Prob(Omnibus):                  0.004   Jarque-Bera (JB):               18.167
# Skew:                           0.039   Prob(JB):                     0.000114
# Kurtosis:                       3.820   Cond. No.                     4.01e+14
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.2e-26. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# This model explains 64.2% of the variation in dependent variable claim. The Durbin-Watson test statistics is 2.011 which indicates that there is no autocorrelation. The Condition Number is 4.01e+14 suggests that there is no collinearity.

# %%
# import SGDRegressor from sklearn to perform linear regression with stochastic gradient descent
from sklearn.linear_model import SGDRegressor

# build the model
linreg_with_SGD = SGDRegressor()

# we fit our model with train data
linreg_with_SGD = linreg_with_SGD.fit(X_train, y_train)

# %%
# we use predict() to predict our values
linreg_with_SGD_predictions = linreg_with_SGD.predict(X_test)

# %% [markdown]
# ### Linear Regression with SGD using GridSearchCV

# %%
# to supress the warnings 
from warnings import filterwarnings
filterwarnings('ignore')

# import gridsearchcv from sklearn to optimize best parameter
from sklearn.model_selection import GridSearchCV

# Grid search 

# alpha is regularization term usually in the range 10.0**-np.arange(1,7).
# this will generate different alpha values like 1.e-01, 1.e-02, 1.e-03, 1.e-04, 1.e-05, 1.e-06

# loss="squared_loss": Ordinary least squares, 

# "l2": L2 norm penalty on coefficients (ridge regression), 
# "l1": L1 norm penalty on coefficients(lasso regression), "elasticnet": Convex combination of L2 and L1    
   
# The learning rate can be either constant or gradually decaying 
    
param_grid = { 'alpha': 10.0 ** -np.arange(1, 7), 
        
               'loss': ['squared_loss'], 
    
               'penalty': ['l2', 'l1', 'elasticnet'],
    
               'learning_rate': ['constant', 'optimal', 'invscaling']
}

# using sklearn’s GridSearchCV, we define our grid of parameters to search over and then run the grid search
clf = GridSearchCV(linreg_with_SGD, param_grid)

# fit the model on train data
clf.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=SGDRegressor(),
#              param_grid={'alpha': array([1.e-01, 1.e-02, 1.e-03, 1.e-04, 1.e-05, 1.e-06]),
#                          'learning_rate': ['constant', 'optimal', 'invscaling'],
#                          'loss': ['squared_loss'],
#                          'penalty': ['l2', 'l1', 'elasticnet']})

# %%
# print the best parameters
# print best alpha value
print('Best alpha:', clf.best_estimator_.alpha)

# print best tolerance
print('Best tol:', clf.best_estimator_.tol) 

# print best starting rate (Use eta0 to specify the starting learning)
print('Best eta0:', clf.best_estimator_.eta0)

# print best learning rate
print('Best learning rate:', clf.best_estimator_.learning_rate)
# Out:
# Best alpha: 0.001
# Best tol: 0.001
# Best eta0: 0.01
# Best learning rate: constant

# %%
# build the model using best parameters
# squared_loss: ordinary least squares loss
# 'eta0': specify the starting learning
linreg_SGD_using_best_parameter = SGDRegressor(alpha=0.001,
                                               eta0=0.01, 
                                               learning_rate='constant')

# fit the SGD model using best parameter
linreg_SGD_using_best_parameter.fit(X_train,y_train)
# Out:
# SGDRegressor(alpha=0.001, learning_rate='constant')

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
y_test_pred1 =linreg_SGD_using_best_parameter.predict(X_test)
y_train_pred1 = linreg_SGD_using_best_parameter.predict(X_train)
r2_test=r2_score(y_test,y_test_pred1)
r2_train=r2_score(y_train,y_train_pred1)

rsme_test =np.sqrt(mean_squared_error(y_test,y_test_pred1))
rsme_train =np.sqrt(mean_squared_error(y_train,y_train_pred1))

mape_test=mean_absolute_error(y_test,y_test_pred1) *100
mape_train=mean_absolute_error(y_train,y_train_pred1)*100

print('r2_train: ',r2_train,  'r2_test: ',r2_test)
print('rsme_train: ',rsme_train , 'rsme_test: ',rsme_test)
print('mape_train: ',mape_train,'mape_test: ',mape_test)
# Out:
# r2_train:  0.522509931863538 r2_test:  0.5135628296185273
# rsme_train:  0.6771616237202828 rsme_test:  0.7289669577313593
# mape_train:  52.998250230772115 mape_test:  55.03923358493128
